# %%
from PIL import Image
import numpy as np
image = Image.open('data/train/1.png')
image_array = np.array(image)

a = []
for i in range(1,33403):
    name = 'data/train/' + str(i) + '.png'
    image = Image.open(name)
    image_array = np.array(image) #shape(height,width,3) - 3 is RGB.
    a.append(image_array)
npArray = np.array(a, dtype='object')
print(npArray.shape)
np.save("data/train_image_data.npy", npArray)
# Out:
# (33402,)
